# %%
import contextlib
from datetime import datetime, date, timedelta
from typing import Optional

import httpx
from fastapi import FastAPI, BackgroundTasks, Query
from sqlmodel import Field, Session, SQLModel, create_engine, select, delete
from sqlalchemy import Column, JSON, BigInteger
from apscheduler.schedulers.asyncio import AsyncIOScheduler
from fastapi.middleware.cors import CORSMiddleware
import asyncio


TARGET_PLAYER = "Kasyu_pwq"
API_URL = f"https://api.wynncraft.com/v3/player/{TARGET_PLAYER}"

async def fetch_and_store_player_data():
    print("正在抓取玩家数据...")
    async with httpx.AsyncClient() as client:
        try:
            response = await client.get(API_URL, timeout=10.0)   # 加上 await
            response.raise_for_status()
            data = response.json()
            print(f"成功抓取玩家数据: {data.get('username', 'unknown')}")
            # 只打印关键字段，避免输出过大
            print("服务器返回的顶级字段:", list(data.keys()))
        except httpx.HTTPError as e:
            print(f"抓取玩家数据失败: {e}")

asyncio.run(fetch_and_store_player_data())   # 启动异步函数
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 31
#      27         except httpx.HTTPError as e:
#      28             print(f"抓取玩家数据失败: {e}")
#      29
#      30 if __name__ == "__main__":
# ---> 31     asyncio.run(fetch_and_store_player_data())   # 启动异步函数
#
# File C:\Python314\Lib\asyncio\runners.py:200, in run(main, debug, loop_factory)
#     170 """Execute the coroutine and return the result.
#     171
#     172 This function runs the passed coroutine, taking care of
#    (...)    196     asyncio.run(main())
#     197 """
#     198 if events._get_running_loop() is not None:
#     199     # fail fast with short traceback
# --> 200     raise RuntimeError(
#     201         "asyncio.run() cannot be called from a running event loop")
#     203 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     204     return runner.run(main)
#
# ...
